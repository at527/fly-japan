# %%
from typing import NamedTuple

norcal_ports = ["SFO", "OAK", "SJC"]
socal_ports = ["LAX", "SNA", "SAN"]
japan_ports = [
    "HND",
    "FUK",
    "CTS",
    "OKA",
    "ITM",
    "NRT",
    "KIX",
    "NGO",
    "KOJ",
    "UKB",
    "SDJ",
    "ISG",
    "KMI",
    "KMJ",
    "NGS",
    "MYJ",
]

prefered_japan_ports = ["HND", "FUK", "KIX", "NGO", "CTS", "OKA"]

start_dates = ["2024-03-21", "2024-03-22", "2024-03-23"]
end_date = ["2024-03-30", "2024-03-31", "2024-04-01"]


class MultiCity(NamedTuple):
    home_out: str
    dest_in: str
    dest_out: str
    home_in: str


def generate_open_jaw(us_ports, japan_ports) -> list[MultiCity]:
    return [
        MultiCity(u_out, j_in, j_out, u_in)
        for u_out in us_ports
        for j_in in japan_ports
        for j_out in japan_ports
        for u_in in us_ports
    ]

# %%
open_jaw_flights = generate_open_jaw(["LAX"], prefered_japan_ports)

len(open_jaw_flights)
# Out:
# 36

# %%
import requests
import json
import config


def flight_search(ports: MultiCity, date_from: str, date_to: str):
    return 0
    

url = "https://api.tequila.kiwi.com/v2/flights_multi"

payload = {
    "requests": [
        {
            "sort": "quality",
            "fly_to": "NRT",
            "fly_from": "LAX",
            "date_from": "22/03/2024",
            "date_to": "22/03/2024",
            "adults": 1,
        },
        {
            "sort": "quality",
            "fly_to": "LAX",
            "fly_from": "KIX",
            "date_from": "01/04/2024",
            "date_to": "01/04/2024",
            "adults": 1,
        },
    ],
}

json_payload = json.dumps(payload)

headers = {
    "Content-Type": "application/json",
    "apikey": config.kiwi_multi_city_key,
}

response = requests.post(url, data=json_payload, headers=headers)

response_data = json.loads(response.text)

# %%
response_data[0]
# Out:
# {'id': '243e209f4d5c00006b08ffba_0|0902243e4d6600000c9d4ac3_0|0902243e4d6600000c9d4ac3_1',
#  'baglimit': {'hand_height': 38,
#   'hand_length': 55,
#   'hand_weight': 5,
#   'hand_width': 20,
#   'hold_dimensions_sum': 158,
#   'hold_height': 52,
#   'hold_length': 78,
#   'hold_weight': 14,
#   'hold_width': 28},
#  'booking_token': 'Ga9uMNbRq6t3l40QeY9V1ghe-4PdjZK7Zna438lBAfGGhEyUom6IeYAwIBc7gs3knHIPbVqPjd_hWzlIMj9U3RxiXAM6bYlC2Pl6nkEDVT-zrc86gBKv3t-19ZAC0JXfLVsIcdzQMe_soygdbj4Z6XcOTklgbq-cehD9h1IdeIZ6dNUJUnfIKip-gVXUkYsrAvfIfr2xUjgWlVIH-XJxY9FQ8srjh-oXESoMyOo4xhTMCr4cLjMuBdINRlFt1CgAFuPEaX249SeVVY90frYOHPzQsk7ybGyPGW9U4tBAH-gZkldqPdtoS9uEe6MGt_BpqNaGb9atPdeyLvqRyr9g5GfgfgKO8XSW1vgaB2IAVO1D4eiYleX5q1D1PEWL_1C-0rSdOx4mGcLEqouqEAtWzx6fv7ppxS4l1ns9b2q6pyPP7Vqt6lYT17ENve1kHAnwBrUI9LEaxIllbnENEdYeKfHiAb3a61QKtXe_OcdBi2wHKGIZ8JZktwgyRkKEY9G-byubIPkKS75ikDifbWOHUKg==',
#  'deep_link': 'https://www.kiwi.com/deep?affilid=at527japanmulti&currency=EUR&flightsId=243e209f4d5c00006b08ffba_0%7C0902243e4d6600000c9d4ac3_0%7C0902243e4d6600000c9d4ac3_1&from=LAX&lang=en&passengers=1&to=NRT&type2=multicity&booking_token=Ga9uMNbRq6t3l40QeY9V1ghe-4PdjZK7Zna438lBAfGGhEyUom6IeYAwIBc7gs3knHIPbVqPjd_hWzlIMj9U3RxiXAM6bYlC2Pl6nkEDVT-zrc86gBKv3t-19ZAC0JXfLVsIcdzQMe_soygdbj4Z6XcOTklgbq-cehD9h1IdeIZ6dNUJUnfIKip-gVXUkYsrAvfIfr2xUjgWlVIH-XJxY9FQ8srjh-oXESoMyOo4xhTMCr4cLjMuBdINRlFt1CgAFuPEaX249SeVVY90frYOHPzQsk7ybGyPGW9U4tBAH-gZkldqPdtoS9uEe6MGt_BpqNaGb9atPdeyLvqRyr9g5GfgfgKO8XSW1vgaB2IAVO1D4eiYleX5q1D1PEWL_1C-0rSdOx4mGcLEqouqEAtWzx6fv7ppxS4l1ns9b2q6pyPP7Vqt6lYT17ENve1kHAnwBrUI9LEaxIllbnENEdYeKfHiAb3a61QKtXe_OcdBi2wHKGIZ8JZktwgyRkKEY9G-byubIPkKS75ikDifbWOHUKg==',
#  'duration': 102000,
#  'pnr_count': 2,
#  'price': 1106,
#  'quality': 1265.22,
#  'route': [{'availability': {'seats': None},
#    'airlines': ['ZG'],
#    'cityFrom': 'Los Angeles',
#    'cityCodeFrom': 'LAX',
#    'cityTo': 'Tokyo',
#    'cityCodeTo': 'TYO',
#    'countryFrom': {'code': 'US', 'name': 'United States'},
#    'countryTo': {'code': 'JP', 'name': 'Japan'},
#    'distance': 8763.4,
#    'fare': {'adults': 553, 'children': 553, 'infants': 553},
#    'flyFrom': 'LAX',
#    'has_airport_change': False,
#    'id': '243e209f4d5c00006b08ffba_0',
#    'local_departure': '2024-03-22T10:35:00.000Z',
#    'utc_departure': '2024-03-22T17:35:00.000Z',
#    'local_arrival': '2024-03-23T14:25:00.000Z',
#    'utc_arrival': '2024-03-23T05:25:00.000Z',
#    'quality': 569.9764,
#    'route': [{'id': '243e209f4d5c00006b08ffba_0',
#      'combination_id': '243e209f4d5c00006b08ffba',
#      'flyFrom': 'LAX',
#      'flyTo': 'NRT',
#      'cityFrom': 'Los Angeles',
#      'cityCodeFrom': 'LAX',
#      'cityTo': 'Tokyo',
#      'cityCodeTo': 'TYO',
#      'local_departure': '2024-03-22T10:35:00.000Z',
#      'utc_departure': '2024-03-22T17:35:00.000Z',
#      'local_arrival': '2024-03-23T14:25:00.000Z',
#      'utc_arrival': '2024-03-23T05:25:00.000Z',
#      'airline': 'ZG',
#      'flight_no': 23,
#      'operating_carrier': '',
#      'operating_flight_no': '',
#      'fare_basis': 'S0ZSA0A',
#      'fare_category': 'M',
#      'fare_classes': 'M',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'equipment': None,
#      'vehicle_type': 'aircraft'}],
#    'throw_away_ticketing': False,
#    'technical_stops': 0,
#    'hidden_city_ticketing': False,
#    'flyTo': 'NRT',
#    'virtual_interlining': False,
#    'baglimit': {'hand_height': 40,
#     'hand_length': 55,
#     'hand_weight': 5,
#     'hand_width': 25,
#     'hold_dimensions_sum': 203,
#     'hold_height': 66,
#     'hold_length': 99,
#     'hold_weight': 14,
#     'hold_width': 38,
#     'personal_item_height': 35,
#     'personal_item_length': 45,
#     'personal_item_weight': 2,
#     'personal_item_width': 25},
#    'bags_price': {'1': 30},
#    'conversion': {'EUR': 553},
#    'duration': {'departure': 42600, 'return': 0, 'total': 42600},
#    'facilitated_booking_available': False,
#    'nightsInDest': None,
#    'pnr_count': 1},
#   {'availability': {'seats': 7},
#    'airlines': ['OZ'],
#    'cityFrom': 'Osaka',
#    'cityCodeFrom': 'OSA',
#    'cityTo': 'Los Angeles',
#    'cityCodeTo': 'LAX',
#    'countryFrom': {'code': 'JP', 'name': 'Japan'},
#    'countryTo': {'code': 'US', 'name': 'United States'},
#    'distance': 9231.61,
#    'fare': {'adults': 553, 'children': 553, 'infants': 553},
#    'flyFrom': 'KIX',
#    'has_airport_change': False,
#    'id': '0902243e4d6600000c9d4ac3_0|0902243e4d6600000c9d4ac3_1',
#    'local_departure': '2024-04-01T09:10:00.000Z',
#    'utc_departure': '2024-04-01T00:10:00.000Z',
#    'local_arrival': '2024-04-01T09:40:00.000Z',
#    'utc_arrival': '2024-04-01T16:40:00.000Z',
#    'quality': 695.23964,
#    'route': [{'id': '0902243e4d6600000c9d4ac3_0',
#      'combination_id': '0902243e4d6600000c9d4ac3',
#      'flyFrom': 'KIX',
#      'flyTo': 'ICN',
#      'cityFrom': 'Osaka',
#      'cityCodeFrom': 'OSA',
#      'cityTo': 'Seoul',
#      'cityCodeTo': 'SEL',
#      'local_departure': '2024-04-01T09:10:00.000Z',
#      'utc_departure': '2024-04-01T00:10:00.000Z',
#      'local_arrival': '2024-04-01T11:00:00.000Z',
#      'utc_arrival': '2024-04-01T02:00:00.000Z',
#      'airline': 'OZ',
#      'flight_no': 115,
#      'operating_carrier': 'OZ',
#      'operating_flight_no': '115',
#      'fare_basis': 'SLOJU3',
#      'fare_category': 'M',
#      'fare_classes': 'Q',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'equipment': None,
#      'vehicle_type': 'aircraft'},
#     {'id': '0902243e4d6600000c9d4ac3_1',
#      'combination_id': '0902243e4d6600000c9d4ac3',
#      'flyFrom': 'ICN',
#      'flyTo': 'LAX',
#      'cityFrom': 'Seoul',
#      'cityCodeFrom': 'SEL',
#      'cityTo': 'Los Angeles',
#      'cityCodeTo': 'LAX',
#      'local_departure': '2024-04-01T14:40:00.000Z',
#      'utc_departure': '2024-04-01T05:40:00.000Z',
#      'local_arrival': '2024-04-01T09:40:00.000Z',
#      'utc_arrival': '2024-04-01T16:40:00.000Z',
#      'airline': 'OZ',
#      'flight_no': 202,
#      'operating_carrier': 'OZ',
#      'operating_flight_no': '202',
#      'fare_basis': 'SLOJU3',
#      'fare_category': 'M',
#      'fare_classes': 'S',
#      'fare_family': '',
#      'return': 0,
#      'bags_recheck_required': False,
#      'vi_connection': False,
#      'guarantee': False,
#      'equipment': None,
#      'vehicle_type': 'aircraft'}],
#    'throw_away_ticketing': False,
#    'technical_stops': 0,
#    'hidden_city_ticketing': False,
#    'flyTo': 'LAX',
#    'virtual_interlining': False,
#    'baglimit': {'hand_height': 38,
#     'hand_length': 57,
#     'hand_weight': 10,
#     'hand_width': 20,
#     'hold_dimensions_sum': 158,
#     'hold_height': 52,
#     'hold_length': 78,
#     'hold_weight': 23,
#     'hold_width': 28},
#    'bags_price': {'1': 30},
#    'conversion': {'EUR': 553},
#    'duration': {'departure': 59400, 'return': 0, 'total': 59400},
#    'facilitated_booking_available': False,
#    'nightsInDest': None,
#    'pnr_count': 1}],
#  'multicity_version': 'new_mc'}
